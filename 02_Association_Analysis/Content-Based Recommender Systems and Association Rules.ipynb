# %% [markdown]
# # Content-Based Recommender Systems and Association Rules
#
# ### Table of Contents
# 1. [Introduction](#introduction)
# 2. [Data Information](#data-info)
# 3. [Load Libraries](#load-libraries)
# 4. [Load Datasets](#load-datasets)
# 5. [Preprocessing](#preprocessing)
# 6. [Association Rules Mining](#association-rules-mining)

# %% [markdown]
# ## Introduction <a class="anchor" id="introduction"></a>
#
# Basic association analysis just deals with the occurrence of one item with another. More complicated analysis can take into consideration the quantity of occurrence, price, and sequence of occurrence, etc. The method for finding association rules through data mining involves the following sequential steps:
# * **Step 1:** Prepare the data in transaction format. An association algorithm needs input data to be formatted in a particular format.
# * **Step 2:** Short-list frequently occurring item sets. Item sets are combination of items. An association algorithm limits the analysis to the most frequently occurring items, so the final rule set extracted in next step is more meaningful.
# * **Step 3:** Generate relevant association rules from item sets. Finally, the algorithm generates and filters the rules based on the interest measure.
#
# One of the benefits of creating a recommender system with association rules it that its recommendations are highly interpretable. While methods like latent factoring methods are powerful, the trends from which their results are gleaned are cryptic. Association rules are simple: "The books you like frequently have these keywords? We'll recommend you more books like that."
#
# While this may seem like a trivial point, remember our design principles! One of our goals was to have users trust that the recommendations we make will be relevant. Giving concrete explanations for each recommended item might give users more of an incentive to believe our recommendations.

# %% [markdown]
# ## Data Information <a class="anchor" id="data-info"></a>
#
# We will use one publically available dataset which will be used to explain the concepts: [Goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)

# %% [markdown]
# ## Load Libraries <a class="anchor" id="load-libraries"></a>
#
# Loading necessary libraries

# %%
import numpy as np 
import pandas as pd

from efficient_apriori import apriori

# %% [markdown]
# ## Load Datasets <a class="anchor" id="load-datasets"></a>
#
# Loading necessary datasets

# %%
# Import datasets
booksRaw =  pd.read_csv("../00_Dataset/goodbooks-10k/books.csv")
tagsRaw = pd.read_csv("../00_Dataset/goodbooks-10k/tags.csv")
bookTagsRaw = pd.read_csv("../00_Dataset/goodbooks-10k/book_tags.csv")
ratingsRaw = pd.read_csv("../00_Dataset/goodbooks-10k/ratings.csv")
to_readRaw = pd.read_csv("../00_Dataset/goodbooks-10k/to_read.csv")

# Merge bookTags and tags
all_tags = pd.merge(bookTagsRaw, tagsRaw, left_on='tag_id', right_on='tag_id', how='inner')
all_tags_grouped = all_tags.groupby("goodreads_book_id")

# Show first five rows of all_tags_grouped
display(all_tags.head())
# Out:
#    goodreads_book_id  tag_id   count tag_name
# 0                  1   30574  167697  to-read
# 1                  2   30574   24549  to-read
# 2                  3   30574  496107  to-read
# 3                  5   30574   11909  to-read
# 4                  6   30574     298  to-read

# %%
# Group ratings by user
ratingsGrouped = ratingsRaw.sort_values('user_id').groupby(by='user_id')

# Show rows of ratings by a particular user (e.g. 1)
ratingsGrouped.get_group(1)
# Out:
#         book_id  user_id  rating
# 117889     1180        1       4
# 488112     4893        1       3
# 625717     6285        1       4

# %% [markdown]
# ## Preprocessing <a class="anchor" id="preprocessing"></a>
#
# Then, make a user profile for each user, storing each rated item with a list of its associated keywords.
#
# The next step is to resolve all conflicts, such as {sci-fi=like} and {sci-fi=dislike}. If we have both of these rules and they have similar confidence levels, we can’t reliably say that the “sci-fi” tag is associated with a like or a dislike.

# %%
class UserProfile:
  def __init__(self, user_id):
    self.userID = user_id;
    self.allTags = [];
    self.highWords = set()
    self.lowWords = set()
    
  def makeUserProfile(self):
      #Separate high rated books and low rated books
      ratedBooks = ratingsGrouped.get_group(self.userID)
      high = ratedBooks[ratedBooks.rating >= 3]
      low = ratedBooks[ratedBooks.rating < 3]
     
      for index, row in high.iterrows():
        #Add tags to list of keywords
        taglist = all_tags[all_tags.goodreads_book_id == row['book_id']].tag_name.tolist()
        
        #Add author names to list of keywords
        authors = booksRaw[booksRaw.book_id == row['book_id']].authors.tolist()
        if (authors != []):
          authors = authors[0].split(",")
          taglist.extend(authors)
            
        self.highWords.union(set(taglist))
        
        #Add rating keyword to transaction
        taglist.append("like")
        
        #Add keyword list to list of all transactions
        if (taglist != []):
          self.allTags.append(taglist)
          
      #repeat this process for the low rated books
      for index, row in low.iterrows():
        taglist = all_tags[all_tags.goodreads_book_id == row['book_id']].tag_name.tolist()
        
        authors = booksRaw[booksRaw.book_id == row['book_id']].authors.tolist()
        if (authors != []):
          authors = authors[0].split(",")
          taglist.extend(authors)
        
        self.lowWords.union(set(taglist))
        
        taglist.append("dislike")
        if (taglist != []):
          self.allTags.append(taglist)
      
      #Remove intersection of low and high keywords from all transactions 
      intersection = self.highWords.intersection(self.lowWords)
      for i in self.allTags:
        j = 0
        while j < len(i):
          if i[j] in intersection:
            i.pop(j)
          j += 1

# %%
user = UserProfile(17566)
user.makeUserProfile()

for i in range(len(user.allTags)):
    print(user.allTags[i])
# Out:
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'young-adult', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 'all-time-favorites', 'default', 'my-books', 'i-own', 'audiobook', 'favorite-books', 'novels', 'favorite', 'audiobooks', 'my-library', 'english', 'british', 'read-in-2016', 'own-it', 'library', 'audio', 'novel', 'read-in-2015', 'shelfari-favorites', 'kindle', 'romance', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'england', 'audio-books', 'read-in-2013', 'read-in-2011', 'borrowed', 'female-author', 'contemporary-fiction', 'wish-list', 'recommended', 'adult', 'book-club', 'adult-fiction', 'literature', 'abandoned', 'audible', 'ebooks', 'audio-book', 'did-not-finish', 'to-read-fiction', 'history', 'historical', 'didn-t-finish', 'australian', 'listened-to', 'bookclub', 'literary', 'read-in-2012', 'europe', 'britain', 'uk', 'want-to-read', 'survival', 'school', 'general-fiction', 'historical-fiction', 'literary-fiction', 'book-group', 'fiction-historical', 'book-club-books', 'book-club-reads', 'historicalfiction', 'read-in-2009', 'medical', 'religion', 'drama', 'australian-authors', 'women', 'women-writers', 'death', 'library-book', 'bookgroup', 'historic-fiction', '17th-century', 'historical-novels', 'historical-novel', '1600s', 'medicine', 'read-2009', 'overdrive', 'middle-ages', 'medieval', 'plague', 'epidemic', 'geraldine-brooks', 'based-on-a-true-story', '17th-century-england', 'Geraldine Brooks', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'books-i-own', 'owned', 'owned-books', 'default', 'my-books', 'audiobook', 'audiobooks', 'my-library', 'books', 'read-in-2016', 'own-it', 'library', 'audio', 'shelfari-favorites', 'to-buy', 'read-in-2017', 'my-bookshelf', 'have', 'read-in-2013', 'not-interested', 'book-club', 'audio-book', 'on-hold', 'hardcover', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'reference', 'maybe', 'own-to-read', 'misc', 'school', 'for-school', 'unread', 'self-help', 'how-to', 'read-in-2009', 'read-2014', 'inspirational', '2006', 'do-not-own', 'next', '2017-reads', 'economics', 'business', 'psychology', 'finance', 'personal-finance', 'money', 'financial', 'investing', 'finances', 'personal-development', 'self-improvement', 'wealth', 'business-finance', 'real-estate', 'personal-growth', 'investment', 'finance-books', 'success', 'personal', 'personal-dev', 'david-bach', 'motivational', 'business-books', 'to-read-business', 'advice', '25-books-for-success', 'money-books', 'library-book', 'lifestyle', 'self-development', 'own-physical-copy', 'entrepreneurship', 'entrepreneur', 'law-of-attraction', 'business-books-to-read', 'professional', 'to-read-2017', 'study', 'business-leadership', 'to-read-self-improvement', 'economics-finance', 'finance-business', 'financial-education', 'to-read-finance', 'books-i-ve-read', 'investments', 'millionaire', 'personal-finance-investing', 'success-books', 'life-transforming-books', 'to-read-money', 'slightedge', 'money-personal-finance', 'money-finance', 'David Bach', 'like']
# ['like']
# ['like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'owned-books', 're-read', 'adventure', 'sci-fi-fantasy', 'default', 'my-books', 'i-own', 'audiobook', 'novels', 'fantasy-sci-fi', 'favorite', 'audiobooks', 'english', 'books', 'mystery', 'library', 'audio', 'novel', 'scifi-fantasy', 'kindle', 'to-buy', 'ebook', 'contemporary', 'science-fiction-fantasy', 'action', 'finished', 'sci-fi', 'humor', 'contemporary-fiction', 'thriller', 'science-fiction', 'action-adventure', 'scifi', 'comedy', 'humour', 'sf', 'book-club', 'adult-fiction', 'literature', 'science', 'fun', 'sci-fi-and-fantasy', 'speculative-fiction', '20th-century', 'abandoned', 'audible', 'ebooks', 'audio-book', 'sf-fantasy', 'sff', 'sciencefiction', 'e-book', 'calibre', 'general', 'american', '1980s', 'paperback', 'read-fiction', 'general-fiction', 'unread', 'not-read', 'politics', 'speculative', 'on-kindle', 'modern-fiction', 'male-author', 'horror', 'crime', 'suspense', 'mystery-thriller', 'thrillers', 'dystopia', 'dystopian', 'paper', 'spec-fic', 'detective', 'boston', 'conspiracy', 'environment', 'environmental', 'ecology', 'activism', 'cyberpunk', 'neal-stephenson', 'stephenson', 'cyber-punk', 'environmentalism', 'wastes', 'hazardous', 'environmentalists', 'eco-thriller', 'mass', 'eco', 'Neal Stephenson', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 'adventure', 'default', 'my-books', 'i-own', 'audiobook', 'audiobooks', 'my-library', 'english', 'read-in-2016', 'own-it', 'library', 'audio', 'read-in-2015', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'audio-books', 'read-in-2013', 'read-in-2011', 'humor', 'wish-list', 'funny', 'home-library', 'comedy', 'humour', 'adult', 'book-club', 'fun', '20th-century', 'humorous', 'abandoned', 'ebooks', 'unfinished', 'did-not-finish', 'e-book', 'history', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'travel', 'non-fic', 'essays', 'american', 'bryson', 'memoir', 'bill-bryson', 'memoirs', 'travel-writing', 'biography', 'travelogue', 'travel-adventure', 'wanderlust', 'travel-books', 'biography-memoir', 'memoir-biography', 'culture', 'travelogues', 'travel-literature', 'autobiography', 'general-non-fiction', 'bookclub', 'favorite-authors', 'travel-lit', 'travels', 'adult-non-fiction', 'bio-memoir', 'non-fiction-travel', 'america', 'usa', 'united-states', 'writing', 'bill', 'states', 'united', 'americana', 'road-trip', 'read-in-2010', '1980s', 'north-america', 'factual', 'viaggi', 'narrativa', 'to-read-travel', 'us', 'paperback', 'read-in-2008', 'journalism', 'books-owned', 'bryson-bill', 'Bill Bryson', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 'all-time-favorites', 'default', 'classics', 'audiobook', 'novels', 'audiobooks', 'english', 'books', 'read-in-2016', 'library', 'audio', 'novel', 'read-in-2015', 'made-me-cry', 'kindle', 'romance', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'read-in-english', 'read-in-2017', 'classic', 'audio-books', 'movie', 'read-in-2011', 'borrowed', 'female-author', 'love', 'contemporary-fiction', 'home-library', 'adult', 'adult-fiction', 'literature', '20th-century', 'ebooks', 'historical', 'american', 'maybe', 'usa', 'short-stories', 'literary', 'movies', 'book-to-movie', 'realistic-fiction', 'general-fiction', 'historical-fiction', 'literary-fiction', 'american-lit', 'american-literature', 'female-authors', 'short', 'stories', 'drama', '2006', 'relationships', 'reviewed', 'university', 'novellas', 'women-writers', 'novella', 'library-books', 'short-story', '4-stars', 'saw-the-movie', 'love-story', 'lgbt', 'lgbtq', 'm-m', 'glbt', 'gay', 'western', 'queer', 'lgbtqia', 'mm', 'm-m-romance', 'cowboys', 'glbtq', 'mm-romance', 'gay-fiction', 'books-to-movies', 'seen-the-movie', 'lgbtqa', 'gay-lit', 'love-stories', 'sad', 'lgbt-fiction', 'westerns', 'friends-to-lovers', 'wyoming', 'made-into-a-movie', 'annie-proulx', 'Annie Proulx', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 're-read', 'all-time-favorites', 'default', 'my-books', 'i-own', 'audiobook', 'favorite', 'audiobooks', 'my-library', 'english', 'read-in-2016', 'own-it', 'library', 'audio', 'read-in-2015', 'shelfari-favorites', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'bookshelf', 'have', 'audio-books', 'other', 'humor', 'wish-list', 'recommended', 'funny', 'humour', 'adult', 'book-club', 'space', 'science', 'abandoned', 'audible', 'ebooks', 'audio-book', 'must-read', 'unfinished', 'did-not-finish', 'on-hold', 'philosophy', 'history', 'nonfiction', 'non-fiction', 'popular-science', 'physics', 'historical', 'to-read-non-fiction', 'reference', 'biology', 'to-read-nonfiction', 'travel', 'non-fiction-to-read', 'non-fic', 'nature', 'astronomy', 'evolution', 'educational', 'natural-history', 'history-of-science', 'didn-t-finish', 'essays', 'general', 'anthropology', 'popular', 'science-nature', 'geology', 'general-science', 'world-history', 'education', 'american', 'nonfic', '21st-century', 'never-finished', 'bryson', 'pop-science', 'maybe', 'cosmology', 'ciencia', 'nonfiction-to-read', 'chemistry', 'own-to-read', 'science-history', 'want', 'couldn-t-finish', 'owned-to-read', 'non-fiction-science', '2000s', 'gave-up-on', 'learning', 'scientific', 'Bill Bryson', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'owned-books', 'default', 'favorite-books', 'novels', 'my-library', 'books', 'library', 'kindle', 'to-buy', 'contemporary', 'read-in-2011', 'finished', 'humor', 'wish-list', 'shelfari-wishlist', 'home-library', 'comedy', 'adult', 'book-club', 'literature', 'fun', 'abandoned', 'did-not-finish', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'non-fic', 'maybe', 'couldn-t-finish', 'owned-to-read', 'memoir', 'memoirs', 'biography', 'biography-memoir', 'memoir-biography', 'autobiography', 'bookclub', 'bio-memoir', 'usa', 'biographies', 'memoir-bio', 'biography-autobiography', 'new-england', 'read-in-2010', 'read-in-2008', 'to-get', 'want-to-read', '2004', 'school', 'book-group', 'fiction-to-read', 'family', 'college', 'poetry', 'boston', 'books-to-read-in-your-20s', '65-books-to-read-in-your-20s', 'homelessness', 'mental-illness', '20s', 'addiction', '65-books-to-read-in-your-20-s', '65-books-you-need-to-read-in-your-2', 'mental-health', 'creative-nonfiction', 'fathers', 'books-to-read-in-your-20-s', 'books-to-read-in-my-20s', 'to-read-in-my-20s', 'bio', 'biographies-memoirs', 'biography-and-memoir', 'memoirs-biographies', 'memoirs-and-biographies', 'memoirs-to-read', 'read-in-your-20s', 'buzzfeed', 'need-to-read-in-your-20s', 'autobiography-memoir', 'biographies-and-memoirs', 'memoir-autobiography', 'quarter-life-crisis', 'books-to-buy', 'drugs', 'memoir-and-biography', 'read-for-class', 'alcoholism', 'books-for-school', 'writers', 'books-to-read-in-your-twenties', '65-books-for-your-20s', '65-books', 'cnf', 'Nick Flynn', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'owned-books', 'default', 'my-books', 'audiobook', 'audiobooks', 'my-library', 'english', 'books', 'library', 'audio', 'shelfari-favorites', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'read-in-2011', 'read-2016', 'other', 'humor', 'wish-list', 'funny', 'humour', 'book-club', 'fun', '20th-century', 'abandoned', 'audible', 'ebooks', 'unfinished', 'calibre', 'history', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'non-fiction-to-read', 'non-fic', 'general', 'american', 'nonfic', 'memoir', 'memoirs', 'biography', 'biography-memoir', 'memoir-biography', 'culture', 'autobiography', 'biographies', 'biographical', '1980s', 'journalism', 'politics', 'social-commentary', 'economics', 'business', 'current-events', 'current-affairs', 'finance', 'money', 'financial', 'investing', 'business-finance', 'investment', 'business-books', 'to-read-business', 'economics-finance', 'investments', 'economy', 'business-economics', 'street', 'work', 'leadership', 'finance-economics', 'biz', 'business-to-read', 'business-and-finance', 'econ', 'wall-street', 'trading', 'michael-lewis', 'economics-business', 'investment-banking', 'economics-and-finance', 'kindle-lending-library', 'markets', 'finance-and-economics', 'financial-crisis', 'financial-history', 'bond-markets', 'banking', 'read-nonfiction', 'business-history', 'business-and-economics', 'wall', 'Michael   Lewis', 'like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'young-adult', 'fiction', 'books-i-own', 'owned', 'ya', 'series', 'favourites', 'owned-books', 're-read', 'adventure', 'all-time-favorites', 'default', 'my-books', 'classics', 'i-own', 'audiobook', '5-stars', 'favorite-books', 'novels', 'favorite', 'audiobooks', 'my-library', 'books', 'read-in-2016', 'my-favorites', 'own-it', 'library', 'audio', 'novel', 'faves', 'shelfari-favorites', 'favourite', 'to-buy', 'to-re-read', 'all-time-favourites', 'ebook', 'contemporary', 'coming-of-age', 'favourite-books', 'classic', 'audio-books', 'borrowed', 'contemporary-fiction', 'wish-list', 'recommended', 'adult', 'book-club', 'adult-fiction', 'literature', '20th-century', 'abandoned', 'audible', 'unfinished', 'did-not-finish', 'to-read-fiction', 'history', 'non-fiction', 'historical', 'didn-t-finish', 'maybe', 'australia', 'memoir', 'australian', 'bookclub', 'in-my-library', 'war', 'realistic-fiction', 'school', 'read-for-school', 'for-school', 'school-books', 'general-fiction', 'historical-fiction', 'literary-fiction', 'book-group', 'race', 'book-club-books', 'book-club-reads', 'african', 'bbc-big-read', 'africa', 'south-africa', 'drama', 'apartheid', 'bryce-courtenay', 'inspirational', 'boxing', 'sports', 'high-school', 'racism', 'australian-authors', 'modern-fiction', 'wwii', 'cultural', 'bildungsroman', 'australian-author', 'all-time-faves', 'Bryce Courtenay', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 'adventure', 'default', 'my-books', 'i-own', 'audiobook', 'audiobooks', 'my-library', 'english', 'read-in-2016', 'own-it', 'library', 'audio', 'read-in-2015', 'shelfari-favorites', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'read-in-english', 'have', 'audio-books', 'read-in-2013', 'read-in-2011', 'read-2015', 'other', 'humor', 'funny', 'shelfari-wishlist', 'home-library', 'comedy', 'humour', 'adult', 'book-club', 'fun', '20th-century', 'humorous', 'abandoned', 'audible', 'ebooks', 'audio-book', 'did-not-finish', 'dnf', 'e-book', 'history', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'travel', 'non-fic', 'essays', 'american', 'bryson', 'memoir', 'bill-bryson', 'memoirs', 'travel-writing', 'biography', 'travelogue', 'travel-adventure', 'wanderlust', 'travel-books', 'biography-memoir', 'memoir-biography', 'culture', 'travelogues', 'travel-literature', 'autobiography', 'geography', 'travel-lit', 'travels', 'travel-memoir', 'bio-memoir', 'non-fiction-travel', 'biographical', 'biography-autobiography', 'essay', '1990s', 'read-in-2012', 'viaggi', 'to-read-travel', 'paperback', 'europe', 'france', 'traveling', 'travelling', 'travel-and-adventure', 'belgium', 'germany', 'viaggio', 'travel-europe', 'Bill Bryson', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'series', 'favourites', 'owned-books', 're-read', 'default', 'my-books', 'classics', 'i-own', 'novels', 'my-library', 'english', 'books', 'mystery', 'library', 'novel', 'read-in-2015', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'read-in-english', 'my-bookshelf', 'classic', 'finished', 'contemporary-fiction', 'thriller', 'wish-list', 'adult', '1001-books', 'book-club', 'adult-fiction', '1001', 'literature', '20th-century', 'abandoned', '1001-books-to-read-before-you-die', 'ebooks', 'must-read', 'unfinished', 'to-read-fiction', 'dnf', 'collection', 'e-book', 'american', 'never-finished', 'own-to-read', 'america', 'usa', 'short-stories', 'united-states', 'literary', 'americana', '1980s', 'narrativa', 'us', '1001-books-you-must-read-before-you', 'general-fiction', 'literary-fiction', 'american-lit', 'american-literature', 'fiction-to-read', 'modern-fiction', 'american-fiction', 'university', 'lit', '1001-import', '1001-books-to-read', '1001-to-read', 'modern', 'new-york', 'nyc', 'novela', 'new-york-city', 'roman', 'magical-realism', 'crime', 'mystery-thriller', 'detective', 'mysteries', 'new', 'postmodern', 'postmodernism', 'post-modern', 'uni', 'paul-auster', 'metafiction', 'auster', 'noir', 'literatura', 'york', 'experimental', 'in-english', 'mystery-crime', 'Paul Auster', ' Art Spiegelman', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 're-read', 'adventure', 'default', 'my-books', 'i-own', 'audiobook', 'audiobooks', 'my-library', 'english', 'british', 'read-in-2016', 'own-it', 'library', 'audio', 'read-in-2015', 'kindle', 'to-buy', 'ebook', 'contemporary', 'read-in-2017', 'england', 'audio-books', 'finished', 'borrowed', 'humor', 'wish-list', 'funny', 'comedy', 'humour', 'adult', 'book-club', 'fun', '20th-century', 'humorous', 'abandoned', 'audible', 'ebooks', 'audio-book', 'unfinished', 'did-not-finish', 'dnf', 'e-book', 'history', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'travel', 'non-fiction-to-read', 'non-fic', 'didn-t-finish', 'essays', 'american', 'nonfic', 'bryson', 'gave-up-on', 'memoir', 'bill-bryson', 'memoirs', 'travel-writing', 'biography', 'travelogue', 'travel-adventure', 'wanderlust', 'travel-books', 'biography-memoir', 'memoir-biography', 'culture', 'travelogues', 'autobiography', 'general-non-fiction', 'geography', 'bio-memoir', 'non-fiction-travel', 'writing', 'bill', 'kindle-books', 'biographical', '1990s', 'paperback', 'europe', 'britain', 'uk', 'bbc-100', '100-books-to-read-before-you-die', 'bbc-list', 'great-britain', 'bbc', 'anglophilia', 'london', 'nf', 'bbc-top-100', 'Bill Bryson', 'like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'owned-books', 'default', 'my-books', 'classics', 'i-own', 'audiobook', 'audiobooks', 'my-library', 'read-in-2016', 'own-it', 'library', 'audio', 'shelfari-favorites', 'kindle', 'to-buy', 'ebook', 'bookshelf', 'have', 'audio-books', 'wish-list', 'home-library', 'adult', 'book-club', 'abandoned', 'audible', 'ebooks', 'audio-book', 'unfinished', 'did-not-finish', 'personal-library', 'calibre', 'history', 'nonfiction', 'non-fiction', 'historical', 'to-read-non-fiction', 'to-read-nonfiction', 'non-fiction-to-read', 'non-fic', 'didn-t-finish', 'general', 'american', 'nonfic', 'own-to-read', 'biography', 'bookclub', 'adult-nonfiction', 'america', 'usa', 'united-states', 'states', 'united', 'biographies', 'in-my-library', 'war', 'school', 'historical-fiction', 'book-group', 'american-history', 'politics', '2006', 'political', 'to-read-history', 'history-politics', 'history-to-read', 'military', 'presidents', 'american-revolution', 'revolutionary-war', 'us-history', 'history-american', 'military-history', 'historical-non-fiction', 'history-biography', 'revolution', 'david-mccullough', 'revolutionary', 'historical-nonfiction', 'non-fiction-history', '18th-century', 'u-s-history', 'mccullough', 'history-non-fiction', 'nonfiction-history', '1776', 'period', 'founding-fathers', 'history-books', 'u-s', '1775-1800', '1775-1783', 'george-washington', 'history-nonfiction', 'history-us', 'David McCullough', 'like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 're-read', 'adventure', 'all-time-favorites', 'default', 'my-books', 'classics', 'i-own', 'audiobook', '5-stars', 'favorite-books', 'novels', 'favorite', 'audiobooks', 'my-library', 'english', 'books', 'read-in-2016', 'mystery', 'own-it', 'library', 'audio', 'novel', 'faves', 'read-in-2015', 'shelfari-favorites', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'read-in-english', 'on-my-shelf', 'classic', 'action', 'movie', 'read-in-2013', 'borrowed', 'other', 'humor', 'contemporary-fiction', 'thriller', 'wish-list', 'adult', 'book-club', 'adult-fiction', 'satire', 'literature', '20th-century', 'abandoned', 'audible', 'ebooks', 'modern-classics', 'to-read-fiction', 'e-book', 'philosophy', 'american', 'usa', 'literary', '1990s', 'read-in-2012', 'movies', 'book-to-movie', 'realistic-fiction', 'general-fiction', 'literary-fiction', 'american-lit', 'american-literature', 'drama', 'modern-fiction', 'modern', 'horror', 'crime', 'suspense', 'dark', 'mystery-thriller', 'thrillers', 'dystopia', 'dystopian', 'mental-illness', 'mental-health', 'postmodern', 'psychology', 'saw-the-movie', 'psychological', 'books-to-movies', 'dark-humor', 'chuck-palahniuk', 'palahniuk', 'transgressive', 'transgressive-fiction', 'unreliable-narrator', 'Chuck Palahniuk', 'like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'owned-books', 'adventure', 'default', 'audiobook', 'audiobooks', 'my-library', 'english', 'library', 'audio', 'shelfari-favorites', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'england', 'audio-books', 'read-in-2013', 'read-in-2011', 'humor', 'wish-list', 'funny', 'home-library', 'comedy', 'humour', 'adult', 'book-club', 'science', '20th-century', 'humorous', 'abandoned', 'audible', 'ebooks', 'audio-book', 'unfinished', 'did-not-finish', 'e-book', 'calibre', 'history', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'travel', 'non-fiction-to-read', 'non-fic', 'essays', 'general', 'bryson', 'memoir', 'bill-bryson', 'memoirs', 'travel-writing', 'biography', 'travelogue', 'travel-adventure', 'travel-books', 'biography-memoir', 'memoir-biography', 'culture', 'autobiography', 'favorite-authors', 'adult-nonfiction', 'adult-non-fiction', 'america', 'usa', 'short-stories', 'social', 'united-states', 'writing', 'life', 'bill', 'states', 'united', 'customs', 'anecdotes', 'literary', 'form', 'and', 'traditions', '20th', 'description', '1971', 'century', 'travelers', 'kindle-books', 'biographies', 'biographical', 'memoir-bio', 'biography-autobiography', 'essay', 'americana', '1990s', 'new-england', 'read-in-2012', 'Bill Bryson', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'books-i-own', 'owned', 'owned-books', 'default', 'my-books', 'audiobook', 'audiobooks', 'english', 'british', 'books', 'read-in-2016', 'own-it', 'library', 'audio', 'read-in-2015', 'shelfari-favorites', 'kindle', 'to-buy', 'ebook', 'contemporary', 'read-in-2017', 'england', 'audio-books', 'read-in-2013', 'borrowed', 'read-2016', 'other', 'humor', 'wish-list', 'funny', 'comedy', 'humour', 'adult', 'book-club', 'literature', '20th-century', 'abandoned', 'audible', 'ebooks', 'audio-book', 'unfinished', 'did-not-finish', 'dnf', 'e-book', 'e-books', 'history', 'nonfiction', 'non-fiction', 'historical', 'to-read-non-fiction', 'reference', 'to-read-nonfiction', 'non-fiction-to-read', 'non-fic', 'didn-t-finish', 'anthropology', 'education', 'nonfic', 'never-finished', 'maybe', 'nonfiction-to-read', 'own-to-read', 'bill-bryson', 'culture', 'favorite-authors', 'america', 'writing', 'kindle-books', '1990s', 'language', 'linguistics', 'proposed-reading-program', 'english-language', 'etymology', 'languages', 'nonfiction-language', 'other-non-fiction', 'words', 'social-science', '2012-2013-first-marking-quarter', 'general-nonfiction', '2012-2013-second-marking-quarter', 'purchased', 'in-my-library', 'social-sciences', 'cultural-studies', 'misc-non-fiction', 'books-about-books', 'read-2017', 'to-get', 'tbr', 'sociology', 'microhistory', 'language-linguistics', '2012-2013-fourth-marking-quarter', 'want-to-read', '2012-2013-third-marking-quarter', 'Bill Bryson', 'like']
# ['like']
# ['like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 're-read', 'all-time-favorites', 'default', 'my-books', 'classics', 'i-own', 'audiobook', '5-stars', 'favorite-books', 'novels', 'favorite', 'my-library', 'books', 'read-in-2016', 'mystery', 'own-it', 'library', 'novel', 'faves', 'read-in-2015', 'shelfari-favorites', 'kindle', 'favourite', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'on-my-shelf', 'classic', 'finished', 'borrowed', 'contemporary-fiction', 'thriller', 'wish-list', 'recommended', 'adult', '1001-books', 'book-club', 'adult-fiction', '1001', 'literature', '20th-century', 'abandoned', '1001-books-to-read-before-you-die', 'modern-classics', 'unfinished', 'history', 'historical', 'maybe', 'bookclub', 'literary', '1980s', 'europe', 'france', 'germany', '1001-books-you-must-read-before-you', 'movies', 'translation', 'school', 'read-for-school', 'for-school', 'general-fiction', 'historical-fiction', 'literary-fiction', 'german', 'bbc-big-read', 'drama', '1001-books-to-read', 'novela', 'french', 'translated', 'roman', 'european-literature', 'روايات', 'favoritos', 'magical-realism', 'horror', 'crime', 'german-literature', 'gothic', 'suspense', 'murder', 'deutsch', 'dark', 'mystery-thriller', 'read-in-german', 'german-lit', 'thrillers', 'perfume', 'crime-thriller', 'stand-alone', 'Patrick Süskind', ' John E. Woods', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'series', 'owned-books', 'default', 'my-books', 'i-own', 'audiobook', 'audiobooks', 'my-library', 'books', 'mystery', 'library', 'audio', '2005', 'kindle', 'to-buy', 'ebook', '2003', 'have', 'audio-books', 'action', 'borrowed', 'books-i-have', 'thriller', 'wish-list', 'part-of-a-series', 'adult', 'adult-fiction', 'audible', 'ebooks', 'audio-book', 'hardcover', 'e-books', 'calibre', 'general', 'american', 'favorite-authors', 'and', '2004', 'african', 'unread', 'read-2013', 'stories', 'my-ebooks', 'crime', 'suspense', 'mystery-thriller', 'thrillers', 'crime-thriller', 'detective', 'mysteries', 'mystery-crime', 'mystery-suspense', 'crime-fiction', 'crime-mystery', 'psychology', 'government', 'suspense-thriller', 'murder-mystery', 'action-thriller', 'psychological', 'police', 'crime-thrillers', 'forensic', 'suspense-mystery', 'mystery-series', 'investigators', 'murder-mysteries', 'procedural', 'kidnapping', 'washington', 'd-c', 'james-patterson', 'patterson', 'patterson-james', 'jamespatterson', 'alex-cross-series', 'james-patterson-books', 'suspence', 'alex-cross', 'james-patterson-alex-cross', 'cross', 'alex', 'psychologists', 'patterson-alex-cross', 'trade', 'patterson--james', 'slave', 'james-patterson-read', 'james-patterson-alex-cross-series', 'patterson-cross', '-d-c--', '-fictitious', 'jp-alex-cross', 'p', 'James Patterson', 'like']
# ['to-read', 'favorites', 'currently-reading', 'books-i-own', 'owned', 'owned-books', 'children', 'default', 'my-books', 'audiobook', 'kids', 'audiobooks', 'my-library', 'books', 'read-in-2016', 'own-it', 'library', 'audio', 'kindle', 'to-buy', 'bookshelf', 'audio-books', 'read-2016', 'love', 'wish-list', 'home-library', 'adult', 'abandoned', 'audible', 'audio-book', 'unfinished', 'did-not-finish', 'partially-read', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'reference', 'to-read-nonfiction', 'non-fiction-to-read', 'educational', 'didn-t-finish', 'education', 'never-finished', 'adult-nonfiction', 'adult-non-fiction', 'read-2017', 'tbr', 'home', 'family', 'parenting', 'parenting-books', 'self-help', 'motherhood', 'child-development', 'parenthood', 'mommy-books', 'read-in-2009', '2016-reads', 'religion', 'inspiration', 'inspirational', 'relationships', 'spiritual', 'religious', '2017-reads', 'psychology', 'personal-development', 'self-improvement', 'personal-growth', 'personal', 'self-development', 'self', 'communication', 'psych', 'christian', 'christian-living', 'faith', 'counseling', 'marriage', 'christian-parenting', 'christian-non-fiction', 'christian-nonfiction', 'to-read-parenting', 'christianity', 'marriage-family', 'gary-chapman', 'christian-books', 'homeschooling', 'parenting-to-read', 'bible-studies', 'relationship', 'non-fiction-parenting', 'chapman', 'homeschool', 'teaching', 'تنمية-بشرية', 'mom', 'must-reads', '2016-reading-list', 'kids-parenting', 'Gary Chapman', ' D. Ross Campbell', 'like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'childrens', 'owned-books', 'children', 'children-s', 'childhood', 'default', 'my-books', 'i-own', 'children-s-books', 'kids', 'my-library', 'own-it', 'childrens-books', 'library', 'youth', 'childhood-favorites', 'kids-books', 'children-s-literature', 'children-s-lit', 'childhood-books', 'classic', 'childrens-lit', 'humor', 'children-s-fiction', 'animals', 'read-as-a-kid', 'classroom-library', 'my-childhood', 'kid-books', 'children-books', 'for-kids', 'baby', 'baby-books', 'child', 'picture-books', 'poetry', 'for-the-kids', 'math', 'food', 'books-we-own', 'rhyme', 'picture-book', 'board-book', 'board-books', 'storytime', 'preschool', 'picture', 'children-s-picture-books', 'kiddos', 'kid-s-books', 'read-to-kids', 'children-s-book', 'read-kids', 'childrensbooks', 'picturebooks', 'silly', 'childrens-picture-books', 'little-kids', 'children-s-read', 'counting', 'kindergarten', 'ece-3601', 'read-with-kids', 'classroom', 'dr-seuss', 'dr-suess', 'seuss', 'easy-reader', 'early-readers', 'early-reader', 'beginning-readers', 'children-s-books-i-own', 'children-read', 'easy-readers', 'young-children', 'favorite-kids-books', 'classroom-books', '1st-grade', 'childrens-read', 'apples', 'numbers', 'rhyming-books', 'counting-books', 'rhymes', 'kids-shelf', 'autumn', 'read-to-my-kids', 'read-to-children', 'dr-seuss-books', 'read-children-s-books', 'repetition', 'reader', 'suess', 'my-kids-books', 'Theo LeSieg', ' Roy McKie', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'young-adult', 'fiction', 'harry-potter', 'books-i-own', 'owned', 'ya', 'favourites', 'magic', 'owned-books', 're-read', 'children', 'children-s', 'all-time-favorites', 'default', 'audiobook', 'kids', 'novels', 'fantasy-sci-fi', 'favorite', 'audiobooks', 'paranormal', 'my-library', 'ya-fantasy', 'teen', 'witches', 'urban-fantasy', 'british', 'jk-rowling', 'supernatural', 're-reads', 'mystery', 'ya-fiction', 'harry-potter-series', 'my-favorites', 'own-it', 'childrens-books', 'library', 'audio', 'young-adult-fiction', 'novel', 'scifi-fantasy', 'wizards', 'faves', 'favorite-series', 'juvenile', 'shelfari-favorites', 'kindle', 'youth', 'romance', 'favourite', 'read-in-2014', 'all-time-favourites', 'childhood-favorites', 'kids-books', '5-star', 'coming-of-age', 'science-fiction-fantasy', 'read-in-2017', 'england', 'children-s-literature', 'children-s-lit', 'magical', 'favs', 'childhood-books', 'potter', 'fantasy-scifi', 'hp', 'classic', '2003', 'boarding-school', 'have', 'audio-books', 'action', 'movie', 'british-literature', 'read-in-2013', 'fantasy-fiction', 'rowling', 'read-in-2011', 'read-multiple-times', 'juvenile-fiction', 'finished', 'young-adult-fantasy', 'read-again', 'ya-books', 'borrowed', 'sci-fi', 'fiction-fantasy', 'childrens-lit', 'female-author', 'fantasia', 'children-young-adult', 'books-i-have', 'mine', 'ya-lit', 'middle-school', 'J.K. Rowling', ' Mary GrandPré', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'series', 'favourites', 'owned-books', 're-read', 'adventure', 'all-time-favorites', 'default', 'my-books', 'classics', 'i-own', 'audiobook', '5-stars', 'favorite-books', 'novels', 'favorite', 'audiobooks', 'my-library', 'english', 'books', 'mystery', 'my-favorites', 'own-it', 'library', 'audio', 'novel', '2005', 'shelfari-favorites', 'kindle', 'romance', 'to-buy', 'ebook', 'contemporary', 'my-bookshelf', 'bookshelf', 'have', 'action', 'movie', 'finished', 'borrowed', 'rory-gilmore-reading-challenge', 'other', 'contemporary-fiction', 'thriller', 'science-fiction', 'home-library', 'action-adventure', 'adult', 'book-club', 'adult-fiction', 'literature', 'abandoned', 'ebooks', 'history', 'historical', 'american', '21st-century', 'france', 'movies', 'read-fiction', 'book-to-movie', 'art', '2004', 'realistic-fiction', 'general-fiction', 'historical-fiction', 'american-literature', 'religion', 'drama', 'modern-fiction', '2006', 'popular-fiction', 'روايات', 'rory-gilmore-challenge', 'rory-gilmore', 'suspense', 'mystery-thriller', 'thrillers', 'religious', 'detective', 'mysteries', 'conspiracy', 'mystery-crime', 'mystery-suspense', 'crime-fiction', 'crime-mystery', 'dan-brown', 'suspense-thriller', 'robert-langdon', 'thriller-mystery', 'brown-dan', 'thriller-suspense', 'brown', 'mystery-thrillers', 'Dan Brown', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'young-adult', 'fiction', 'books-i-own', 'owned', 'ya', 'series', 'favourites', 'magic', 'owned-books', 're-read', 'adventure', 'sci-fi-fantasy', 'childhood', 'all-time-favorites', 'default', 'my-books', 'classics', 'reread', 'i-own', '5-stars', 'favorite-books', 'novels', 'fantasy-sci-fi', 'favorite', 'audiobooks', 'read-more-than-once', 'my-library', 'english', 'british', 'books', 're-reads', 'my-favorites', 'own-it', 'library', 'novel', 'scifi-fantasy', 'faves', 'shelfari-favorites', 'kindle', 'favourite', 'to-buy', 'to-re-read', 'all-time-favourites', 'ebook', 'science-fiction-fantasy', 'favourite-books', 'my-bookshelf', 'bookshelf', 'fantasy-scifi', 'classic', 'have', 'british-literature', 'fantasy-fiction', 'finished', 'sci-fi', 'fiction-fantasy', 'fantasia', 're-reading', 'epic-fantasy', 'wish-list', 'science-fiction', 'high-fantasy', 'fantasy-and-sci-fi', 'home-library', 'adult', '1001-books', 'adult-fiction', '1001', 'literature', 'sci-fi-and-fantasy', 'speculative-fiction', '20th-century', 'abandoned', '1001-books-to-read-before-you-die', 'ebooks', 'sf-fantasy', 'modern-classics', 'must-read', 'unfinished', 'to-reread', 'on-hold', 'gave-up-on', 'paperback', 'j-r-r-tolkien', 'lord-of-the-rings', 'epic', 'classic-literature', 'jrr-tolkien', 'middle-earth', 'mythology', 'war', '1001-books-you-must-read-before-you', 'movies', 'fantasy-science-fiction', 'tolkien', 'english-literature', 'J.R.R. Tolkien', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'fantasy', 'favorites', 'currently-reading', 'young-adult', 'fiction', 'books-i-own', 'owned', 'ya', 'series', 'favourites', 'magic', 'owned-books', 're-read', 'adventure', 'sci-fi-fantasy', 'childhood', 'all-time-favorites', 'default', 'my-books', 'reread', 'i-own', 'audiobook', 'favorite-books', 'novels', 'fantasy-sci-fi', 'favorite', 'audiobooks', 'paranormal', 'my-library', 'ya-fantasy', 'teen', 'witches', 'urban-fantasy', 'read-in-2016', 'supernatural', 'mystery', 'ya-fiction', 'own-it', 'library', 'audio', 'young-adult-fiction', 'read-in-2015', 'kindle', 'romance', 'to-buy', 'read-in-2014', 'to-re-read', 'ebook', 'coming-of-age', 'england', 'on-my-shelf', 'boarding-school', 'audio-books', 'read-in-2013', 'read-in-2011', 'young-adult-fantasy', 'ya-books', 'borrowed', 'ya-lit', 'friendship', 'wish-list', 'youngadult', 'teen-books', 'book-club', 'abandoned', 'ebooks', 'unfinished', 'did-not-finish', 'dnf', 'history', 'historical', 'didn-t-finish', 'maybe', 'read-in-2012', 'read-in-2010', 'tbr', 'historical-fiction', '19th-century', 'on-my-bookshelf', 'read-in-2009', 'high-school', 'reviewed', 'victorian', 'gothic', 'library-books', 'chick-lit', '4-stars', 'historical-fantasy', 'historical-romance', 'first-in-series', 'teen-fiction', 'y-a', 'libba-bray', 'paranormal-romance', 'trilogy', 'gemma-doyle', 'ya-historical-fiction', 'ya-paranormal', 'victorian-era', 'Libba Bray', 'like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['like']
# ['to-read', 'favorites', 'currently-reading', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 're-read', 'adventure', 'all-time-favorites', 'default', 'my-books', 'i-own', 'audiobook', 'audiobooks', 'my-library', 'english', 'read-in-2016', 'own-it', 'library', 'audio', 'read-in-2015', 'kindle', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'read-in-2017', 'audio-books', 'finished', 'borrowed', 'read-2015', 'humor', 'wish-list', 'recommended', 'funny', 'home-library', 'comedy', 'humour', 'adult', 'book-club', 'humorous', 'abandoned', 'audible', 'ebooks', 'audio-book', 'unfinished', 'did-not-finish', 'e-book', 'e-books', 'history', 'nonfiction', 'non-fiction', 'to-read-non-fiction', 'to-read-nonfiction', 'travel', 'non-fic', 'nature', 'didn-t-finish', 'essays', 'nonfic', 'bryson', '2000s', 'gave-up-on', 'australia', 'memoir', 'bill-bryson', 'memoirs', 'travel-writing', 'biography', 'travelogue', 'travel-adventure', 'australian', 'wanderlust', 'travel-books', 'biography-memoir', 'memoir-biography', 'adventure-travel', 'culture', 'travelogues', 'around-the-world', 'travel-literature', 'animals', 'autobiography', 'listened-to', 'general-non-fiction', 'bookclub', 'geography', 'oceania', 'favorite-authors', 'travel-lit', 'travels', 'adult-nonfiction', 'adult-non-fiction', 'travel-memoir', 'travel-memoirs', 'bio-memoir', 'misc', 'non-fiction-travel', 'Bill Bryson', 'like']
# ['to-read', 'favorites', 'currently-reading', 'young-adult', 'fiction', 'books-i-own', 'owned', 'favourites', 'owned-books', 'all-time-favorites', 'default', 'my-books', 'i-own', 'audiobook', '5-stars', 'favorite-books', 'novels', 'favorite', 'audiobooks', 'my-library', 'my-favorites', 'own-it', 'library', 'audio', 'novel', 'shelfari-favorites', 'kindle', 'romance', 'to-buy', 'read-in-2014', 'ebook', 'contemporary', 'coming-of-age', 'audio-books', 'read-in-2013', 'read-in-2011', 'finished', 'female-author', 'friendship', 'contemporary-fiction', 'wish-list', 'recommended', 'home-library', 'adult', 'book-club', 'adult-fiction', 'literature', 'abandoned', 'ebooks', 'audio-book', 'did-not-finish', 'to-read-fiction', 'history', 'historical', 'didn-t-finish', 'culture', 'around-the-world', 'bookclub', 'literary', 'read-in-2012', 'read-in-2010', 'read-in-2008', 'want-to-read', 'school', 'general-fiction', 'historical-fiction', 'literary-fiction', 'book-group', 'fiction-historical', 'book-club-books', '19th-century', 'book-club-reads', 'historicalfiction', 'family', 'female-authors', 'read-in-2009', 'drama', 'cultural', 'women', 'relationships', 'asia', 'chick-lit', 'asian', 'multicultural', 'historic-fiction', 'china', 'asian-literature', 'chinese', 'asian-lit', 'chinese-culture', 'lisa-see', 'asian-fiction', 'book-club-picks', 'asian-culture', 'foot-binding', 'book-club-book', 'book-club-read', 'book-club-selections', 'international', 'footbinding', 'Lisa See', 'like']
# ['like']
# ['dislike']
# ['dislike']
# ['dislike']
# ['dislike']
# ['dislike']
# ['dislike']
# ['dislike']
# ['dislike']

# %% [markdown]
# ## Association Rules Mining <a class="anchor" id="association-rules-mining"></a>
#
#
# For each user profile, we mine all of its association rules for a given minimum support and minimum confidence.
#
# The antecedent in content based system differs from collaborative filtering, where both the antecedent and consequent of rules are ratings. These rules will have some set of keywords in the left-hand side, and a consequent rating on the right.
# Once we have all of these rules for each user, we can use them to start predict ratings.

# %%
print("Length of allTags: ", sum(len(tag) for tag in user.allTags))
# Out:
# Length of allTags:  2825

# %%
allItemsets, allRules = list(apriori(user.allTags,
                                     min_confidence=0.3,
                                     min_support=0.13))
print("Without minimum confidence and support, there would be over rules! Here we narrow it down to just", len(allRules),".")
# Out:
# Without minimum confidence and support, there would be over rules! Here we narrow it down to just 17896 .

# %%
for i in range(len(allRules)):
    print(allRules[i])
# Out:
# {currently-reading} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned-books} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {to-read} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {owned-books} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own, currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {books-i-own, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own, currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {books-i-own, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own, currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {books-i-own, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, like} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {currently-reading} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {books-i-own, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {books-i-own, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, currently-reading} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {books-i-own, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {currently-reading, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, like} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {default} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, default} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {books-i-own, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {default, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {favorites, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, like} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {favorites} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {favorites, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {favorites, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, favorites} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {books-i-own, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {favorites, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, like} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {library} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {library, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {library, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {library, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, library} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {books-i-own, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {library, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {books-i-own, like} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {books-i-own, like} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {books-i-own, like} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, owned-books} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {books-i-own, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books, to-read} -> {books-i-own} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, to-read} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own, owned-books} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {books-i-own, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {books-i-own, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {books-i-own} -> {owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {default} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {favorites, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {favorites} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {favorites, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {favorites, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {favorites, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {library} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {library, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {library, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {library, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {library, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {currently-reading, like} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {currently-reading, like} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {currently-reading, like} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, owned-books} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books, to-read} -> {currently-reading} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {default, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {default, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {favorites, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {favorites} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {default, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {default, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {favorites, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {default, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {default, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {favorites, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {default, favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {default, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {favorites, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {library} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {library, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {default, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {default, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {library, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {default, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {default, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {library, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {default, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {default, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {library, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {default, like} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {default, like} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {default, like} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {default, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, owned-books} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {default, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {default, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {default, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {default, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books, to-read} -> {default} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {default, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {default, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {library} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {library, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {favorites, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {favorites, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {library, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {favorites, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {favorites, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {library, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {favorites, library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {favorites, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {library, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {favorites, like} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {favorites, like} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {favorites, like} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {favorites, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, owned-books} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {favorites, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {favorites, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {favorites, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {favorites, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books, to-read} -> {favorites} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {favorites, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {favorites, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# {library, like} -> {owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {library, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books} -> {library} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books} -> {like} (conf: 1.000, supp: 0.134, lift: 1.043, conv: 41237113.402)
# ...
# {currently-reading, favorites, library, like} -> {default, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, owned-books, to-read} -> {favorites, library, like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, owned, to-read} -> {favorites, library, like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, owned, owned-books} -> {favorites, library, like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, like, to-read} -> {favorites, library, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, like, owned-books} -> {favorites, library, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, like, owned} -> {favorites, library, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, library, to-read} -> {favorites, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, library, owned-books} -> {favorites, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, library, owned} -> {favorites, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, library, like} -> {favorites, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, favorites, to-read} -> {library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, favorites, owned-books} -> {library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, favorites, owned} -> {library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, favorites, like} -> {library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, favorites, library} -> {like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, owned-books, to-read} -> {currently-reading, default, favorites, library, like} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books, to-read} -> {currently-reading, default, favorites, library, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned, to-read} -> {currently-reading, default, favorites, library, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned, owned-books} -> {currently-reading, default, favorites, library, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books, to-read} -> {currently-reading, default, favorites, like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned, to-read} -> {currently-reading, default, favorites, like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned, owned-books} -> {currently-reading, default, favorites, like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like, to-read} -> {currently-reading, default, favorites, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like, owned-books} -> {currently-reading, default, favorites, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like, owned} -> {currently-reading, default, favorites, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books, to-read} -> {currently-reading, default, library, like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned, to-read} -> {currently-reading, default, library, like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned, owned-books} -> {currently-reading, default, library, like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like, to-read} -> {currently-reading, default, library, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like, owned-books} -> {currently-reading, default, library, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like, owned} -> {currently-reading, default, library, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library, to-read} -> {currently-reading, default, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library, owned-books} -> {currently-reading, default, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library, owned} -> {currently-reading, default, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library, like} -> {currently-reading, default, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books, to-read} -> {currently-reading, favorites, library, like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned, to-read} -> {currently-reading, favorites, library, like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned, owned-books} -> {currently-reading, favorites, library, like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like, to-read} -> {currently-reading, favorites, library, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like, owned-books} -> {currently-reading, favorites, library, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like, owned} -> {currently-reading, favorites, library, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library, to-read} -> {currently-reading, favorites, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library, owned-books} -> {currently-reading, favorites, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library, owned} -> {currently-reading, favorites, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library, like} -> {currently-reading, favorites, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites, to-read} -> {currently-reading, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites, owned-books} -> {currently-reading, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites, owned} -> {currently-reading, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites, like} -> {currently-reading, library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites, library} -> {currently-reading, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books, to-read} -> {default, favorites, library, like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned, to-read} -> {default, favorites, library, like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned, owned-books} -> {default, favorites, library, like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like, to-read} -> {default, favorites, library, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like, owned-books} -> {default, favorites, library, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like, owned} -> {default, favorites, library, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library, to-read} -> {default, favorites, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library, owned-books} -> {default, favorites, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library, owned} -> {default, favorites, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library, like} -> {default, favorites, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites, to-read} -> {default, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites, owned-books} -> {default, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites, owned} -> {default, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites, like} -> {default, library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites, library} -> {default, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, to-read} -> {favorites, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, owned-books} -> {favorites, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, owned} -> {favorites, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, like} -> {favorites, library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, library} -> {favorites, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default, favorites} -> {library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books, to-read} -> {currently-reading, default, favorites, library, like, owned} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, to-read} -> {currently-reading, default, favorites, library, like, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned, owned-books} -> {currently-reading, default, favorites, library, like, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, to-read} -> {currently-reading, default, favorites, library, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned-books} -> {currently-reading, default, favorites, library, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {like, owned} -> {currently-reading, default, favorites, library, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, to-read} -> {currently-reading, default, favorites, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned-books} -> {currently-reading, default, favorites, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, owned} -> {currently-reading, default, favorites, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library, like} -> {currently-reading, default, favorites, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, to-read} -> {currently-reading, default, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned-books} -> {currently-reading, default, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, owned} -> {currently-reading, default, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, like} -> {currently-reading, default, library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites, library} -> {currently-reading, default, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, to-read} -> {currently-reading, favorites, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned-books} -> {currently-reading, favorites, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, owned} -> {currently-reading, favorites, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, like} -> {currently-reading, favorites, library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, library} -> {currently-reading, favorites, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default, favorites} -> {currently-reading, library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, to-read} -> {default, favorites, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned-books} -> {default, favorites, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, owned} -> {default, favorites, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, like} -> {default, favorites, library, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, library} -> {default, favorites, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, favorites} -> {default, library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading, default} -> {favorites, library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {to-read} -> {currently-reading, default, favorites, library, like, owned, owned-books} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned-books} -> {currently-reading, default, favorites, library, like, owned, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {owned} -> {currently-reading, default, favorites, library, like, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {library} -> {currently-reading, default, favorites, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {favorites} -> {currently-reading, default, library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {default} -> {currently-reading, favorites, library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)
# {currently-reading} -> {default, favorites, library, like, owned, owned-books, to-read} (conf: 1.000, supp: 0.134, lift: 7.462, conv: 865979381.443)

# %% [markdown]
# ## Rating Prediction <a class="anchor" id="rating-prediction"></a>

# %% [markdown]
# Let’s say we are predicting ratings for user A. For each item i, we check if the attributes of i “fire” any of A’s rules. A rule is said to be fired by an item if the left-hand side of the rules is a subset the item’s attributes. We then sort this set of rules by descending confidence levels.

# %%
highRules = set(filter(lambda rule: 'like' in rule.rhs and len(rule.rhs) == 1, allRules))
lowRules = set(filter(lambda rule: 'dislike' in rule.rhs and len(rule.rhs) == 1, allRules))

# %%
total = 0
rules_fired = 0
predicted_ratings = []

# for book in all_tags_grouped['goodreads_book_id'].unique():
for book in all_tags_grouped['goodreads_book_id'].unique():
    # print(book)
    explanation = []
    tags = set(all_tags_grouped.get_group(book[0])['tag_name'].unique())
    # print(list(highRules))
    for rule in highRules:
        rule_words = set([key for key in rule.lhs])
        #print("flag: ", book)
        if rule_words.issubset(tags):
            
            explanation.extend([key for key in rule.lhs])
            total += 1
            
    for rule in lowRules:
        rule_words = set([key for key in rule.lhs])
        
        if rule_words.issubset(tags):
            explanation.extend([key for key in rule.lhs])
            total -= 1
    predicted_ratings.append([booksRaw[booksRaw["book_id"] == book[0]].title,explanation,total])
    total = 0
    #print("The predicted rating for book ", book[0], "is ", predicted_rating)

# %%
predicted_ratings = pd.DataFrame(predicted_ratings,columns=["book_name","explanation","predicted_rating"])
display(predicted_ratings.head())
# Out:
#                                            book_name  \
# 0  26    Harry Potter and the Half-Blood Prince (...
# 1  20    Harry Potter and the Order of the Phoeni...
# 2  1    Harry Potter and the Sorcerer's Stone (Ha...
# 3  17    Harry Potter and the Prisoner of Azkaban...
# 4  23    Harry Potter and the Goblet of Fire (Har...
#
#                                          explanation  predicted_rating
# 0  [currently-reading, default, library, currentl...               254
# 1  [currently-reading, default, library, currentl...               254
# 2  [currently-reading, default, library, currentl...               254
# 3  [currently-reading, default, library, currentl...               254
# 4  [owned, owned-books, to-read, owned, owned-boo...                31

# %% [markdown]
# In conclusion, rule-based recommender systems are simple in concept, but flexible and highly interpretable. They can be used as a model for content-based system, but also for collaborative filtering (a rule might look like {Likes x} → {Dislikes y}).
